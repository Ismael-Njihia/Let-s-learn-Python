# %% [markdown]
# <a href="https://www.kaggle.com/code/ishmaelnjihia/python-class-notes?scriptVersionId=108717566" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
st = "hello"
print(len(st))

# %%
ST ="desktop"
ST[2:5:2]

# %%
ST ="desktop"
ST[2:]

# %%
ST ="desktop"
ST[:5]

# %%
st = "culture"
st[::-1]

# %%
myname ="ishmael"
myname[::-1]

# %%
N = input("enter a word")
if N== N[::-1]:
    print(N, "is a palindrome\n")
else:
    print(N, "Is not a palindrome")

# %%
def isPalindrome(s):
	return s == s[::-1]

s = input("Enter a word: ")
ans = isPalindrome(s)

if ans:
	print(s, "is a palindrome!")
else:
	print(s, "Is not a palindrome")

# %%
ST ="Ishmael njihia"
print(ST.replace("njihia","Unknown"))
print(ST)
