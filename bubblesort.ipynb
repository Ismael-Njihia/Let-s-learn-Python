# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x = [1000,5000,10000,20000,30000,40000,50000,60000, 70000]

y = [0.102399349212646488,2.500598669052124,10.054120779037476,32.60221529006958,75.72606635093689,135.92857694625854,212.19371390342712,316.32299757003784,455.876389503479]

plt.plot(x,y)

# %%
# -- coding: utf-8 --
"""
Created on Tue Jun  7 19:15:08 2022

@author: David Oriedi
"""
import random
import time



start = time.perf_counter()

def bubbleSort(arr):
    n = len(arr)
 
    # Traverse through all array elements
    for i in range(n-1):
    # range(n) also work but outer loop will
    # repeat one time more than needed.
 
        # Last i elements are already in place
        for j in range(0, n-i-1):
 
            # traverse the array from 0 to n-i-1
            # Swap if the element found is greater
            # than the next element
            if arr[j] > arr[j + 1] :
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
 
# Driver code to test above
#arr = [64, 34, 25, 12, 22, 11, 90]
arr=[(random.randint(0,70000)) for i in range(70000)]
 
start_t = time.time()
bubbleSort(arr)
end_t = time.time()

finish = time.perf_counter()

 
print ("Sorted array is:")
for i in range(len(arr)):
    print ("% d" % arr[i],end=" ")
    
print(f'Finished in {round(finish-start,3)} second(s)')
code_t=end_t - start_t
print('Time taken by the algorithm: ', end_t - start_t)
# Out:
# Sorted array is:
# ...
