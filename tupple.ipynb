# %%
t =tuple()
N = int(input('Enter the population size: \n'))

for i in range (N):
    x = eval(input("Enter the score at: "+str(i)+"\n"))
    t = t+(x,)
    #display the total score
print('Total score = ', sum(t)) 

#display the number of score
print('Population size = ', len(t))
#display the min and max
print('Highest = ',max(t), 'lowest = ',min(t))
#display the average
print('Average = ',sum(t)/len(t))
#Variance of the score

z=0
u = sum(t)/len(t)
for i in range (len(t)):
    z = (z+(t[i]-u)) **2 
    
    var = z/N
    sd = (var)**(1/2)
print("Variance is = ", z)
print("Standard deviation = ",sd)
# Out:
# Enter the population size:
#  2
# Enter the score at: 0
#  23
# Enter the score at: 1
#  23
# Total score =  46
# Population size =  2
# Highest =  23 lowest =  23
# Average =  23.0
# Variance is =  0.0
# Standard deviation =  0.0

# %%
l =list()
t2 = tuple()
N = int(input('Enter the population size: \n'))

for i in range (N):
    x = eval(input("Enter the score at: "+str(i)+"\n"))
    l.append(x)
    #converting to a tuple
    t1 = tuple(l)
    #square
    t2 = t2 + (l[i]**2,)
t1 = tuple(l)
#display the values stored
print("values stored = ", sorted(t1))

#Values squared

print("Values squared = ", t2)

#Display the third value
print("the third value = ",t1[2])

#Display the average
print("The average value is = ", sum(t1)/len(t1))

#Look for duplicates value
t3 = tuple()
for i in range(len(t1)):
    if t1[i] not in t3:
        t3 = t3 +(t1[i],)
print("Tupple with no duplicates = ",t3)
# Out:
# Enter the population size:
#  5
# Enter the score at: 0
#  23
# Enter the score at: 1
#  23
# Enter the score at: 2
#  23
# Enter the score at: 3
#  23
# Enter the score at: 4
#  23
# values stored =  [23, 23, 23, 23, 23]
# Values squared =  (529, 529, 529, 529, 529)
# the third value =  23
# The average value is =  23.0
# Tupple with no duplicates =  (23,)
