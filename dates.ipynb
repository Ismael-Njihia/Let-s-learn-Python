# %%
from datetime import date
d = int(input("Enter the date: \n"))
m = int(input("Enter the month: \n"))
y = int(input("Enter the year: \n"))

dt = date(y,m,d) #using date() constructor
print("The date is: ", dt)
# Out:
# Enter the date:
#  12
# Enter the month:
#  8
# Enter the year:
#  2022
# The date is:  2022-08-12
