# %%
#recursive function
def fact(N):
    if(N == 0):
        return 1
    else:
        return N * fact(N-1)
    
def Get():
    x = eval(input("Enter an integer"))
    y = fact(x)
    print(x, "!=",y)
Get()
# Out:
# Enter an integer 5
# 5 != 120
